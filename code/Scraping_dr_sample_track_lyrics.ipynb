# %% [markdown]
# # Getting Song Lyrics
#
# from Genius
#
# for dr sample tracks from Spotify playlists

# %%
# client id oaVTKqlIXns6qFZo-KMDJ98kWME1tigxZKO4fp4jevr2poAMQixUGLwi56RfZxYU
# client secret xkxYifkJ6oaQ2zGIl4-22lNQ4XZ3JE3wYiiE4iY7nAoUpfvPJM_GIXr1urd3Bd9bb56GBKyLpzKYYPZmozJGfg
# access token 3kl3bgPgBFar-5_Awek8AJiIM4f3SJrbTsFn2kP02iLY_xYujpEd8BobJ-Npi_1x

# %%
# import needed libraries

import lyricsgenius
import pandas as pd
import numpy as np
import getpass
from tqdm import tqdm
from bs4 import BeautifulSoup
import requests

# %%
# import data

dr_tracks = pd.read_csv('../data/dr_sample/dr_tracks_id_title_expl_artist_album.csv')

# %%
dr_tracks.head()
# Out:
#    Unnamed: 0                      id      track_title  track_explicit  \
# 0           0  5mrNkGIEJ0pSdXIR0eMwZQ        Bandolero            True
# 1           1  1EFbLCDFWIIiC6IMgthYsN  El Niño (Alarm)            True
# 2           2  3czNqQU3YvEcxaxIz16nb7         Es kocht            True
# 3           3  4oqjF0RgQmtGGogG3paqOT         Barbaren            True
# 4           4  5E3dnmFiGepqED3KpwJalV     Sierra Leone            True
#
#   track_artist
# 0        Azero
# 1        Azero
# 2        Azero
# 3        Azero
# 4        Azero

# %%
# getting a list of clean artist and track titles

artisttweaked = [a.split(" feat. ")[0].split(" x ")[0].replace(" & ", " ").replace(" / ", " ").replace("'", "").replace(" [DE]", "").replace(".", " ").replace("?", "").replace("¿", "").replace(" +", "").replace(" [UK]", "").replace(" [2019]", "").replace(" [Live]", "") for a in dr_tracks['track_artist']]
titletweaked = [t.split(" feat. ")[0].split(" x ")[0].replace(" & ", " ").replace(" / ", " ").replace("'", " ").replace(" [DE]", "").replace(".", " ").replace("?", "").replace("¿", "").replace(" +", "").replace(" [UK]", "").replace(" [2019]", "").replace(" [Live]", "") for t in dr_tracks['track_title']]

searchterms = []
for a, t in zip(artisttweaked, titletweaked):
    s = a + " " + t
    searchterms.append(s)

# %%
searchterms
# Out:
# ['Azero Bandolero',
#  'Azero El Niño (Alarm)',
#  'Azero Es kocht',
#  'Azero Barbaren',
#  'Azero Sierra Leone',
#  'Azero Bela',
#  'Azero Von A nach B',
#  'Azero Vollzeit',
#  'Azero Alles so gewollt',
#  'Azero Nightpaket',
#  'Azero Lobby',
#  'Azero Outro',
#  'Klapse Mane Auf Schleife',
#  'Klapse Mane 18 Durch 3',
#  'Klapse Mane Suicide',
#  'Klapse Mane Nasenbluten',
#  'Klapse Mane Schieflage',
#  'Klapse Mane 1000 Liter',
#  'Klapse Mane Sonnenseite',
#  'Klapse Mane Hand in Hand',
#  'Klapse Mane Alleine',
#  'Klapse Mane Ein bisschen Zeit',
#  'Klapse Mane Brot',
#  'Klapse Mane Intro',
#  'Klapse Mane Worum geht s',
#  'Klapse Mane Dämonen',
#  'Klapse Mane X- Files',
#  'Klapse Mane Playa de Coca',
#  'Klapse Mane Lila Kreis',
#  'Klapse Mane IgetHigh',
#  'Klapse Mane Immer noch alles',
#  'Klapse Mane Theodor-Wenzel-Boyz (Paranoid)',
#  'Klapse Mane 3 Uhr Nachts',
#  'Klapse Mane Worum geht s - Remix',
#  'Klapse Mane Amon Isis',
#  'Klapse Mane Outro',
#  'Riccardo All In',
#  'Riccardo Gemein wie 10',
#  'Riccardo Italy Mode',
#  'Riccardo Cosa nostra',
#  'Riccardo Bereit',
#  'Riccardo Bugs Bunny',
#  'Riccardo RI-LOADED',
#  'Riccardo KBM',
#  'Riccardo McQUEENs',
#  'Riccardo Move',
#  'Riccardo Aus den Augen aus dem Sinn',
#  'Riccardo Tageslicht',
#  'Riccardo Atemzug',
#  'Riccardo Preach',
#  'Riccardo Ciao ciao',
#  'LUVRE47 Noch ein Handy',
#  'LUVRE47 Ausgang',
#  'LUVRE47 Rückbank',
#  'LUVRE47 Todeskreis',
#  'LUVRE47 Schule',
#  'LUVRE47 Kreisrund',
#  'LUVRE47 Um die Welt',
#  'grim104 Das Grauen',
#  'grim104 Graf Grim',
#  'grim104 Hölle',
#  'grim104 This Great Evil',
#  'grim104 Abel  19',
#  'grim104 Ratten im Gemäuer',
#  'grim104 Unter der Stadt',
#  'grim104 Gespenster (Skit)',
#  'grim104 Geist',
#  'grim104 Juri Gagarin',
#  'grim104 Frosch',
#  'grim104 Crystal Meth in Brandenburg',
#  'grim104 Dreck Scheisse Pisse',
#  'grim104 Der kommende Aufstand',
#  'grim104 2  Mai',
#  'grim104 Cro Hafti Herzl',
#  'grim104 Ich töte Anders Breivik',
#  'grim104 Sternstunden der Bedeutungslosigkeit',
#  'Zate Amelie',
#  'Zate Anker',
#  'Zate Das ist meine Geschichte',
#  'Zate Das ist meine Geschichte 2',
#  'Zate Das ist meine Geschichte 3',
#  'Zate Eiskalter Engel',
#  'Zate Ich bin immer noch da',
#  'Zate Ich brauche dich',
#  'Zate Letztes Lied',
#  'Zate Mum',
#  'Zate Rest In Peace Caro',
#  'Zate Seit du weg bist',
#  'Zate Du brauchst mich nicht',
#  'Zate Abschiedsbrief Teil 1 - Remix',
#  'Zate Abschiedsbrief Teil 2 - Remix',
#  'Zate Suizid Teil 1 - Remix',
#  'Zate Suizid Teil 2 - Remix',
#  'Zate Nicht aufgeben',
#  'Zate Tote Mädchen lügen nicht - Remix',
#  'Zate Ich kann das nicht',
#  'Zate Mama',
#  'Zate Meld dich',
#  'Zate Was ist nur passiert',
#  'Zate Ich muss gehen',
#  'Zate Du - Remix',
#  'Zate Ode an dich',
#  'Zate Revue',
#  'Zate Tag ein Tag aus',
#  'Zate Zu dir',
#  'Zate Für jeden Augenblick',
#  'Zate Mona Lisa',
#  'Zate Broke Teil 2',
#  'Zate Broke Teil 1',
#  'Zate Depression',
#  'Zate Ein letztes mal, ich liebe dich',
#  'Zate Ist schon ok',
#  'Zate Mein Herz',
#  'Zate Mein Leben',
#  'Zate Sag wo bist du jetzt',
#  'Zate Zirkus 2',
#  'Zate S O S',
#  'Zate Denken',
#  'Zate Sepia',
#  'Zate Leb wohl, aber meld dich',
#  'Zate Bis zum Tod',
#  'Zate Tag ein Tag aus',
#  'Zate Tränen',
#  'Zate Zirkus',
#  'Zate Du',
#  'Zate Kopf gegen Herz',
#  'Stanley Benz vor meiner Tür',
#  'Stanley Starterpack',
#  'Stanley Back to the Roots',
#  'Stanley Drehen im Kreis',
#  'Stanley Geschichten aus der Hood',
#  'Stanley Ich genieße',
#  'Stanley Einbrecher Sound',
#  'Stanley Guten Morgen Deutschland',
#  'Stanley Kein Ding',
#  'Stanley Mit den Jungs',
#  'Stanley Chauvi',
#  'Stanley Solange',
#  'Stanley Ganz Kriminell',
#  'Stanley Jedes Mal',
#  'Stanley 3512',
#  'Stanley Ich Puffe',
#  'Stanley Sag mir',
#  'Stanley Hamburg Billstedt',
#  'Stanley Boogie',
#  'Stanley Komm mit uns',
#  'Aylo Wach',
#  'Aylo Over',
#  'Aylo Teardrops',
#  'Aylo Vermisst',
#  'Aylo Daydream',
#  'Aylo Gänsehaut',
#  'Aylo Sehnsucht',
#  'Aylo Sag mir',
#  'Aylo Renn weg',
#  'Aylo Kein Limit',
#  'Aylo Für uns zwei',
#  'Aylo Wer trägt Schwarz',
#  'Aylo Handy aus',
#  'Aylo Kavalier',
#  'Aylo Teardrops - Slow Version',
#  'Aylo Komm wir springen',
#  'Aylo Daydream - Zombic Felix Schorn Remix',
#  'Endzone Trap Teacher',
#  'Endzone Dreck am Stecken',
#  'Endzone Apotheken Tatt',
#  'Endzone Shorty Ya',
#  'Endzone Saruch',
#  'Endzone Makatussin',
#  'Endzone Harekets',
#  'Endzone 4 Schritte',
#  'Endzone Nympho',
#  'Endzone Vernetzt',
#  'Endzone Kein Cent',
#  'Endzone Ich hab s',
#  'Endzone Wildcard: Endziel',
#  'Endzone 61 Grad',
#  'Kontra K Du willst es',
#  'Kontra K Tiefschwarz (feat  Samra)',
#  'Kontra K Gangster Gentlemen',
#  'Kontra K Puste sie weg',
#  'Kontra K Sonne',
#  'Kontra K Für dich geh ich rein (feat  BACI)',
#  'Kontra K Freunde',
#  'Kontra K Soll so sein (feat  BTNG)',
#  'Kontra K Wie gemacht dafür',
#  'Kontra K Namen',
#  'Kontra K Auf der Klinge',
#  'Kontra K Alles dreht sich (feat  Capital Bra)',
#  'Kontra K Karma 2 0',
#  'Kontra K Sie rennt (feat  Ufo361)',
#  'Kontra K Sirenen (feat  AK Ausserkontrolle)',
#  'Kontra K Nochmal (feat  Rico Skepsis)',
#  'Kontra K Gift (feat  Alicia Awa)',
#  'Kontra K Nicht wert (feat  Jah Khalib)',
#  'Kontra K Der Mond und ich',
#  'Kontra K Lass mich lieber allein',
#  'Kontra K Du willst es',
#  'Kontra K Tiefschwarz (feat  Samra)',
#  'Kontra K Gangster Gentlemen',
#  'Kontra K Puste sie weg',
#  'Kontra K Sonne',
#  'Kontra K Für dich geh ich rein (feat  BACI)',
#  'Kontra K Freunde',
#  'Kontra K Soll so sein (feat  BTNG)',
#  'Kontra K Wie gemacht dafür',
#  'Kontra K Namen',
#  'Kontra K Auf der Klinge',
#  'Kontra K Alles dreht sich (feat  Capital Bra)',
#  'Kontra K Karma 2 0',
#  'Kontra K Sie rennt (feat  Ufo361)',
#  'Kontra K Sirenen (feat  AK Ausserkontrolle)',
#  'Kontra K Nochmal (feat  Rico Skepsis)',
#  'Kontra K Gift (feat  Alicia Awa)',
#  'Kontra K Nicht wert (feat  Jah Khalib)',
#  'Kontra K Der Mond und ich',
#  'Kontra K Lass mich lieber allein',
#  'Kontra K Weine nicht',
#  'Kontra K Warnung',
#  'Kontra K Nur ein Grund (feat  Jah Khalib)',
#  'Kontra K Ihre Sprache',
#  'Kontra K Benzin',
#  'Kontra K Kampfgeist 4',
#  'Kontra K Blei (feat  Veysel)',
#  'Kontra K So lang (feat  Rico Skepsis)',
#  'Kontra K Letzte Träne',
#  'Kontra K Schicksal',
#  'Kontra K Immer weiter',
#  'Kontra K Bleib weg von mir (feat  RAF Camora)',
#  'Kontra K Farben',
#  'Kontra K Alles weg',
#  'Kontra K Sag mir wo (feat  BTNG)',
#  'Kontra K Honig (feat  Gringo)',
#  'Kontra K Alles was sie will',
#  'Kontra K Zu viele (feat  Joshi Mizu)',
#  'Kontra K Skimaske (feat  AK Ausserkontrolle)',
#  'Kontra K Niemals vergessen',
#  'Kontra K Weine nicht',
#  'Kontra K Warnung',
#  'Kontra K Nur ein Grund (feat  Jah Khalib)',
#  'Kontra K Ihre Sprache',
#  'Kontra K Benzin',
#  'Kontra K Kampfgeist 4',
#  'Kontra K Blei (feat  Veysel)',
#  'Kontra K So lang (feat  Rico Skepsis)',
#  'Kontra K Letzte Träne',
#  'Kontra K Schicksal',
#  'Kontra K Immer weiter',
#  'Kontra K Bleib weg von mir (feat  RAF Camora)',
#  'Kontra K Farben',
#  'Kontra K Alles weg',
#  'Kontra K Sag mir wo (feat  BTNG)',
#  'Kontra K Honig (feat  Gringo)',
#  'Kontra K Alles was sie will',
#  'Kontra K Zu viele (feat  Joshi Mizu)',
#  'Kontra K Skimaske (feat  AK Ausserkontrolle)',
#  'Kontra K Niemals vergessen',
#  'Maximilian Diehn Motten',
#  'Maximilian Diehn Ganz ok',
#  'Maximilian Diehn Himmel',
#  'Maximilian Diehn Zu leicht',
#  'Maximilian Diehn Oder nicht',
#  'Maximilian Diehn Respekt (feat  Fatal)',
#  'Maximilian Diehn Was weißt du schon',
#  'Maximilian Diehn Ellenbogen raus (feat  SSIO)',
#  'Maximilian Diehn Setz Dich (feat  AK Ausser Kontrolle Gzuz)',
#  'Maximilian Diehn Egal wer kommt (feat  Bausa)',
#  'Maximilian Diehn Fußstapfen (feat  Rico)',
#  'Maximilian Diehn Hunger',
#  'Maximilian Diehn Geschwister (feat  BTNG)',
#  'Maximilian Diehn Fame (feat  RAF Camora)',
#  'Maximilian Diehn Ich hab dich',
#  'Maximilian Diehn Zwischen Himmel Hölle',
#  'Maximilian Diehn Ohne Dich',
#  'Maximilian Diehn Besser geh',
#  'Kontra K Hoch',
#  'Maximilian Diehn Jetzt oder niemals',
#  'Maximilian Diehn Blut tauscht man nicht ein (feat  Nizi Skinny Al)',
#  'Maximilian Diehn Verbrannt (feat  Fatal)',
#  'Maximilian Diehn Kein Tag frei (feat  Rico)',
#  'Maximilian Diehn Spotlight (feat  Skepsis)',
#  'Maximilian Diehn Real Recognize Real (feat  Sick Jacken)',
#  'Maximilian Diehn Soldaten 2 0 (Live)',
#  'Maximilian Diehn Gute Nacht (Live)',
#  'Maximilian Diehn Mehr als ein Job (Live)',
#  'Maximilian Diehn Diamanten (Live)',
#  'Maximilian Diehn 2 Seelen (Live)',
#  'Fatal Luft Liebe',
#  'Fatal Paradies (feat  Nizi)',
#  'Rico Sperling Deja Vu',
#  'Rico Sperling Wie machst du das',
#  'Kontra K Motten',
#  'Kontra K Ganz ok',
#  'Kontra K Himmel',
#  'Kontra K Zu leicht',
#  'Kontra K Oder nicht',
#  'Kontra K Respekt (feat  Fatal)',
#  'Kontra K Was weißt du schon',
#  'Kontra K Ellenbogen raus (feat  SSIO)',
#  'Kontra K Setz Dich (feat  AK Ausser Kontrolle Gzuz)',
#  'Kontra K Egal wer kommt (feat  Bausa)',
#  'Kontra K Fußstapfen (feat  Rico)',
#  'Kontra K Hunger',
#  'Kontra K Geschwister (feat  BTNG)',
#  'Kontra K Fame (feat  RAF Camora)',
#  'Kontra K Ich hab dich',
#  'Kontra K Zwischen Himmel Hölle',
#  'Kontra K Ohne Dich',
#  'Kontra K Besser geh',
#  'Kontra K Hoch',
#  'Kontra K Jetzt oder niemals',
#  'Kontra K Blut tauscht man nicht ein (feat  Nizi Skinny Al)',
#  'Kontra K Verbrannt (feat  Fatal)',
#  'Kontra K Kein Tag frei (feat  Rico)',
#  'Kontra K Spotlight (feat  Skepsis)',
#  'Kontra K Real Recognize Real (feat  Sick Jacken)',
#  'Kontra K Soldaten 2 0 - Live',
#  'Kontra K Gute Nacht - Live',
#  'Kontra K Mehr als ein Job - Live',
#  'Kontra K Diamanten - Live',
#  'Kontra K 2 Seelen - Live',
#  'Fatal Luft Liebe',
#  'Fatal Paradies (feat  Nizi)',
#  'Rico Deja Vu',
#  'Rico Wie machst du das',
#  'Kontra K Ratten',
#  'Kontra K Diamanten',
#  'Kontra K Mehr als ein Job',
#  'Kontra K Hände weg (feat  Rico)',
#  'Kontra K 2 Seelen',
#  'Kontra K Power',
#  'Kontra K Plem Plem (feat  Raf Camora Bonez MC)',
#  'Kontra K Einfach',
#  'Kontra K Gute Nacht',
#  'Kontra K Mosaik (feat  Rico)',
#  'Kontra K Wie du',
#  'Kontra K Gift (feat  BTNG AK Ausser Kontrolle)',
#  'Kontra K Instinkt',
#  'Kontra K Jedes Mal (feat  Fatal Skepsis)',
#  'Kontra K Kreis (feat  Bausa)',
#  'Kontra K Lass mal',
#  'Kontra K Glücklichen',
#  'Kontra K Lass mich los',
#  'Kontra K Ratten - Instrumental',
#  'Kontra K Diamanten - Instrumental',
#  'Kontra K Mehr als ein Job - Instrumental',
#  'Kontra K Hände weg - Instrumental',
#  'Kontra K 2 Seelen - Instrumental',
#  'Kontra K Power - Instrumental',
#  'Kontra K Plem Plem - Instrumental',
#  'Kontra K Einfach - Instrumental',
#  'Kontra K Gute Nacht - Instrumental',
#  'Kontra K Mosaik - Instrumental',
#  'Kontra K Wie du - Instrumental',
#  'Kontra K Gift - Instrumental',
#  'Kontra K Instinkt - Instrumental',
#  'Kontra K Jedes Mal - Instrumental',
#  'Kontra K Kreis - Instrumental',
#  'Kontra K Lass mal - Instrumental',
#  'Kontra K Glücklichen - Instrumental',
#  'Kontra K Lass mich los - Instrumental',
#  'Kontra K Chameleon (feat  BTNG)',
#  'Kontra K Scherbenpuzzle (feat  BTNG)',
#  'Kontra K In meinen Schuhen',
#  'Kontra K Nie wie wir',
#  'Kontra K Schlaf (feat  BTNG Bonez MC)',
#  'Kontra K Immernoch hier',
#  'Rico Keine echte Liebe',
#  'Fatal Küss nicht meine Augen',
#  'Omik K Tausende Fragen',
#  'Mike Jay Ich wollte nie so sein (feat  Undacover)',
#  'Ghazy030 Bitte weine nicht um mich (feat  Skinny AL)',
#  'Kontra K Ratten - Track Commentary',
#  'Kontra K Diamanten - Track Commentary',
#  'Kontra K Mehr als ein Job - Track Commentary',
#  'Kontra K Hände weg (feat  Rico) - Track Commentary',
#  'Kontra K 2 Seelen - Track Commentary',
#  'Kontra K Power - Track Commentary',
#  'Kontra K Plem Plem (feat  Raf Camora Bonez MC) - Track Commentary',
#  'Kontra K Einfach - Track Commentary',
#  'Kontra K Gute Nacht - Track Commentary',
#  'Kontra K Mosaik (feat  Rico) - Track Commentary',
#  'Kontra K Wie du - Track Commentary',
#  'Kontra K Gift (feat  BTNG AK Ausser Kontrolle) - Track Commentary',
#  'Kontra K Instinkt - Track Commentary',
#  'Kontra K Jedes Mal (feat  Fatal Skepsis) - Track Commentary',
#  'Kontra K Kreis (feat  Bausa) - Track Commentary',
#  'Kontra K Lass mal - Track Commentary',
#  'Kontra K Glücklichen - Track Commentary',
#  'Kontra K Lass mich los - Track Commentary',
#  'Kontra K Atme tief ein',
#  'Kontra K Ikarus',
#  'Kontra K Bis hierher',
#  'Kontra K Mitleid',
#  'Kontra K Hoffnung',
#  'Kontra K Wie könnt ich',
#  'Kontra K Gut Böse (feat  Bonez MC, Nizi RAF Camora)',
#  'Kontra K Jetzt erst recht',
#  'Kontra K Paradies (feat  Rico)',
#  'Kontra K Nie wieder',
#  'Kontra K Kampfgeist 3',
#  'Kontra K An deiner Seite',
#  'Kontra K Labyrinth',
#  'Kontra K Brot stapeln (feat  Fatal, Rico Skinny Al)',
#  'Kontra K Geist',
#  'Kontra K Tagtraum',
#  'Kontra K Sohn',
#  'Kontra K Bittersüß (feat  Haudegen)',
#  'Kontra K Atme tief ein - Instrumental',
#  'Kontra K Ikarus - Instrumental',
#  'Kontra K Bis hierher - Instrumental',
#  'Kontra K Mitleid - Instrumental',
#  'Kontra K Hoffnung - Instrumental',
#  'Kontra K Wie könnt ich - Instrumental',
#  'Kontra K Gut Böse - Instrumental',
#  'Kontra K Jetzt erst recht - Instrumental',
#  'Kontra K Paradies - Instrumental',
#  'Kontra K Nie wieder - Instrumental',
#  'Kontra K Kampfgeist 3 - Instrumental',
#  'Kontra K An deiner Seite - Instrumental',
#  'Kontra K Labyrinth - Instrumental',
#  'Kontra K Brot stapeln - Instrumental',
#  'Kontra K Geist - Instrumental',
#  'Kontra K Tagtraum - Instrumental',
#  'Kontra K Sohn - Instrumental',
#  'Kontra K Bittersüß - Instrumental',
#  'Kontra K Courage',
#  'Kontra K Diemak (feat  Bonez MC)',
#  'Kontra K Nur noch eine Kugel (feat  Skinny Al Skepsis)',
#  'Kontra K Geblendet (feat  Fatal)',
#  'Kontra K Betonwüste',
#  'Kontra K Zeitlos (feat  Fatal)',
#  'Kontra K Jeden Tag',
#  'Kontra K Aus dem Schatten    (Intro)',
#  'Kontra K Erfolg ist kein Glück',
#  'Kontra K Atme den Regen',
#  'Kontra K Bleib ruhig',
#  'Kontra K Kampfgeist 2',
#  'Kontra K Mein Herz',
#  'Kontra K Hassliebe',
#  'Kontra K Spring!',
#  'Kontra K Träume',
#  'Kontra K Eiskalt (feat  Daniel Spencer)',
#  'Kontra K Hassen ist leicht (feat  Skinny Al)',
#  'Kontra K Macht ($$$)',
#  'Kontra K Karma',
#  'Kontra K Augen zu',
#  'Kontra K Disziplin',
#  'Kontra K Wir brennen',
#  'Kontra K    ins Licht (Outro)',
#  'Skinny Al Chrom Chrime',
#  'Skinny Al Kein Herz',
#  'Skinny Al Mein ala bester   ',
#  'Skinny Al Hast du Angst',
#  'Skinny Al Mach ma schnell',
#  'Skinny Al Du auch - Skit',
#  'Skinny Al Wenn sie fluchen',
#  'Skinny Al Hast du Angst - Remix',
#  'Skinny Al Chrom Chrime - Clip Version',
#  'Kontra K Vater Sohn',
#  'Kontra K Gedankenaustausch',
#  'Kontra K W I R ',
#  'Kontra K Rücken zur Wand',
#  'Kontra K Fels in der Brandung',
#  'Kontra K So wach',
#  'Kontra K Gönn dir',
#  'Kontra K K E L L E R',
#  'Kontra K 101%',
#  'Kontra K Therapie',
#  'Kontra K Generation Crack',
#  'Kontra K Vergib uns',
#  'Kontra K Glaub mir',
#  'Kontra K Eigentlich',
#  'Kontra K In der Stille',
#  'Kontra K Nebel',
#  'Kontra K Mach was',
#  'Kontra K Für die    ',
#  'Kontra K Schlaf gut',
#  'Kontra K Bis bald und auf Wiedersehen',
#  'Kontra K Wenn der Tag anbricht',
#  'Kontra K Verdammt Ja!',
#  'Kontra K Du willst n Banger',
#  'Kontra K Ich seh dich',
#  'Kontra K Auf Stop!!!',
#  'Kontra K Unterm Strich',
#  'Kontra K Andere machen Mukke - Remix',
#  'Kontra K Intro',
#  'Kontra K Alles anders',
#  'Kontra K Kampfgeist',
#  'Kontra K Zu kurz',
#  'Kontra K Tick Tack',
#  'Kontra K Rückendeckung',
#  'Kontra K Schön',
#  'Kontra K Großstadtdschungel',
#  'Kontra K 120 Prozent',
#  'Kontra K Ihr und wir',
#  'Kontra K Ein Teil',
#  'Kontra K Immer noch nicht satt   ',
#  'Kontra K Traumfrau',
#  'Kontra K Zeit',
#  'Kontra K Mein Revier - Bonus Track',
#  'Kontra K Andere machen Mukke, wir machen Ernst - Bonus Track',
#  'Kontra K Alphabet - Bonus Track',
#  'Kontra K Führe mich nicht in Versuchung - Bonus Track',
#  'Kontra K Ein Atemzug',
#  'Kontra K Wieder ein Tag',
#  'Kontra K Wir waren nie HipHop',
#  'Kontra K Endlich Erwachsen',
#  'Kontra K Rabenschwarz',
#  'Kontra K Blutsport 2',
#  'Kontra K Augen im Rücken',
#  'Kontra K Vollkontakt',
#  'Kontra K Gangstafilm',
#  'Kontra K Er und ich',
#  'Kontra K Ich erinner mich',
#  'Kontra K Bleib klar',
#  'Kontra K Stadtrundfahrt',
#  'Kontra K Unsere Generation',
#  'Kontra K Ich habs satt',
#  'Kontra K Der nette alte Mann',
#  'Kontra K Es frisst deine Seele auf',
#  'Kontra K Straßenkinder',
#  'Kontra K Ja ja',
#  'Kontra K Das Maschinengewehr rotiert',
#  'Kontra K Damals und heute',
#  'Die Fantastischen Vier Hitisn',
#  'Die Fantastischen Vier Zusammen',
#  'Die Fantastischen Vier Tunnel',
#  'Die Fantastischen Vier Endzeitstimmung',
#  'Die Fantastischen Vier Hitisn - Hitnapperz Remix',
#  'Die Fantastischen Vier Zusammen',
#  'Die Fantastischen Vier Tunnel - Spidermän Untergrund Remix',
#  'Die Fantastischen Vier Endzeitstimmung - Endmix',
#  'Die Fantastischen Vier Captain Fantastic',
#  'Die Fantastischen Vier Tunnel',
#  'Die Fantastischen Vier Zusammen',
#  'Die Fantastischen Vier Fantanamera',
#  'Die Fantastischen Vier Moduland Y',
#  'Die Fantastischen Vier Hitisn',
#  'Die Fantastischen Vier Watchmen',
#  'Die Fantastischen Vier Alle (Skit)',
#  'Die Fantastischen Vier Endzeitstimmung',
#  'Die Fantastischen Vier Hot',
#  'Die Fantastischen Vier Henson J J  Barkley (Skit)',
#  'Die Fantastischen Vier Aller Anfang Ist Yeah',
#  'Die Fantastischen Vier Das Ist Mein Ding',
#  'Die Fantastischen Vier Affen Mit Waffen',
#  'Die Fantastischen Vier Hitisn Reprise',
#  'Die Fantastischen Vier Weitermachen',
#  'Die Fantastischen Vier A-Seite - Live im Supersense',
#  'Die Fantastischen Vier B-Seite - Live im Supersense',
#  'Die Fantastischen Vier Eines Tages - Live im Supersense',
#  'Die Fantastischen Vier Eines Tages',
#  'Die Fantastischen Vier Jetzt passt auf - Live in Berlin',
#  'Rayvanny Lala',
#  'Rayvanny Mama',
#  'Rayvanny Kiuno',
#  'Rayvanny Marry Me',
#  'Rayvanny Zamani',
#  'Rayvanny Waongo',
#  'Rayvanny Juu',
#  'Rayvanny Woza',
#  'Rayvanny Ex Boyfriend',
#  'Rayvanny Teamo',
#  'Rayvanny One',
#  'Rayvanny Vumilia',
#  'Rayvanny Sweet Melody',
#  'Rayvanny Mama La Mama',
#  'Rayvanny I Love You',
#  'Rayvanny Naogopa',
#  'Frauenarzt Backstage',
#  'Frauenarzt Doppeldeckerfick',
#  'Frauenarzt Bounce zu dem Beat',
#  'Frauenarzt Böse Mädchen',
#  'Frauenarzt Zeig uns alles',
#  'Frauenarzt Autobass',
#  'Frauenarzt Shake-N-Bass',
#  'Frauenarzt Illegale Geschäfte',
#  'Frauenarzt Daddy Fetisch Baby',
#  'Frauenarzt Lap Dance',
#  'Frauenarzt Wenn der Bums Bus rollt',
#  'Frauenarzt Wir sind GOTT',
#  'Frauenarzt Ich Schwöre',
#  'Frauenarzt Kein Geheimnis',
#  'Frauenarzt Bis sie mich töten',
#  'Frauenarzt Egal was du sagst',
#  'Frauenarzt Jemand muss es tun',
#  'Frauenarzt Was ist los',
#  'Frauenarzt Es ist Zeit',
#  'Frauenarzt Ich tu  nicht viel',
#  'Frauenarzt Einer klatscht',
#  'Frauenarzt Sag wie es ist',
#  'Frauenarzt Untergrund Rap',
#  'Frauenarzt Vorhang auf 3',
#  'Frauenarzt Weltuntergang',
#  'Frauenarzt Der blutige Pfad Gottes',
#  'Taktloss Antigott',
#  'Frauenarzt Wir sind GOTT - Instrumental',
#  'Frauenarzt Ich Schwöre - Instrumental',
#  'Frauenarzt Kein Geheimnis - Instrumental',
#  'Frauenarzt Bis sie mich töten - Instrumental',
#  'Frauenarzt Egal was du sagst - Instrumental',
#  'Frauenarzt Jemand muss es tun - Instrumental',
#  'Frauenarzt Was ist los - Instrumental',
#  'Frauenarzt Es ist Zeit - Instrumental',
#  'Frauenarzt Ich tu  nicht viel - Instrumental',
#  'Frauenarzt Einer klatscht - Instrumental',
#  'Frauenarzt Sag wie es ist - Instrumental',
#  'Frauenarzt Untergrund Rap - Instrumental',
#  'Frauenarzt Vorhang auf 3 - Instrumental',
#  'Frauenarzt Weltuntergang - Instrumental',
#  'Frauenarzt Der blutige Pfad Gottes - Instrumental',
#  'Taktloss Antigott - Instrumental',
#  'Frauenarzt KKF',
#  'Frauenarzt Zieh dein Shirt aus',
#  'Frauenarzt Nachbarviertelterrorist',
#  'Frauenarzt Blaulicht',
#  'Frauenarzt Alles Gute',
#  'Frauenarzt Fickfinger',
#  'Frauenarzt Eine Kugel',
#  'Frauenarzt Buuuh',
#  'Frauenarzt Westberlin',
#  'Frauenarzt Ketten raus Kragen hoch',
#  'Frauenarzt 666',
#  'Frauenarzt Mein Bae',
#  'Frauenarzt Wir geben keinen Fick',
#  'Frauenarzt KKF - Kool Savas Smoove RMX',
#  'Frauenarzt Zieh dein Shirt aus - RMX',
#  'Frauenarzt Nachbarviertelterrorist - RMX',
#  'Frauenarzt Blaulicht - RMX',
#  'Frauenarzt Alles Gute - DJ Desue RMX',
#  'Frauenarzt Fickfinger - RMX',
#  'Frauenarzt Eine Kugel - RMX',
#  'Frauenarzt Buuuh - DJ Reckless RMX',
#  'Frauenarzt Westberlin - RMX',
#  'Frauenarzt Ketten raus Kragen hoch - RMX',
#  'Frauenarzt 666 - RMX',
#  'Frauenarzt Mein Bae - RMX',
#  'Frauenarzt Wir geben keinen Fick - RMX',
#  'Frauenarzt Feiern mit den Pleitegeiern',
#  'Frauenarzt Die Welt is nich genug',
#  'Frauenarzt Sag niemals nie',
#  'Frauenarzt Casino Royal',
#  'Frauenarzt Spieler',
#  'Frauenarzt Leben Lang',
#  'Frauenarzt Komm Komm',
#  'Frauenarzt Untergrund Tape',
#  'Frauenarzt Zahltag',
#  'Frauenarzt 4 Asse',
#  'Frauenarzt Liebesgrüße aus Paris',
#  'Frauenarzt Bonus Track',
#  'Cro ALLES DOPE',
#  'Cro 1 INSTAGRAMM',
#  'Cro GOOD VIBES',
#  'Cro SMOOTH',
#  'Cro BLESSED (feat  Capital Bra)',
#  'Cro WACH',
#  'Cro SUPERWOMAN',
#  'Cro NICE!',
#  'Cro DIAMONDS',
#  'Cro SYGL (feat  Shindy)',
#  ...]

# %%
token = getpass.getpass()
# Out:
# ········

# %%
# accessing genius API

client_access_token = token
genius = lyricsgenius.Genius(client_access_token, remove_section_headers=True,
                 skip_non_songs=True, excluded_terms=["Remix", "Live", "Edit", "Mix", "Club"])

# %%
# getting lyrics for sample tracks

lyrics_lst = []

test = ['Die Fantastischen Vier Single','Cro GOOD VIBES', 'Kontra K Lass mich los']

for searchy in tqdm(test):
    try:
        songsind = genius.search_songs(searchy)
        url = url = songsind['hits'][0]['result']['url']
        page = requests.get(url)
        html = BeautifulSoup(page.text, "html.parser") # Extract the page's HTML as a string

        # Scrape the song lyrics from the HTML
        lyrics = html.find("div", class_="lyrics").get_text()
        lyrics_lst.append(lyrics)
    except:
        lyrics_lst.append(np.nan)
        
len(lyrics_lst)
# Out:
# 100%|██████████| 3/3 [00:09<00:00,  3.06s/it]

# %%
# getting lyrics per track

lyrics_lst = []

for searchy in tqdm(searchterms):
    try:
        songsind = genius.search_songs(searchy)
        url = songsind['hits'][0]['result']['url']
        page = requests.get(url)
        html = BeautifulSoup(page.text, "html.parser") # Extract the page's HTML as a string

        # Scrape the song lyrics from the HTML
        lyrics = html.find("div", class_="lyrics").get_text()
        lyrics_lst.append(lyrics)
    except:
        lyrics_lst.append(np.nan)
# Out:
#  17%|█▋        | 4696/28077 [1:54:47<22:13:07,  3.42s/it]

# %%
len(lyrics_lst)

# %%
# checking for how many tracks I did not get lyrics

lyrics_lst.count(np.nan)

# %%
# assigning lyrics to tracks in df

dr_tracks['lyrics'] = lyrics

# %%
# checking data

dr_tracks.info()
