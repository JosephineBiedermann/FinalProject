# %% [markdown]
# # Getting data 1 - top100 tracks

# %% [markdown]
# For my first Hypothesis I need to get all the top100 tracks from the official German charts from 2010-2021.
#
# **0 Hypothesis: The audio features of deutsch rap tracks became more similar to the audio features of tracks found in the top100 German charts from 2010-2021**
#
# I am looking for the following info to scrape:
# - artist
# - track title
# - label
# - rank
# - week
#
# Once I sucessfully scraped the desired data, I will store it in a csv file for further processing.

# %%
# importing libraries

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# url I want to scrape

url = 'https://www.offiziellecharts.de/charts/single/for-date-1620390068000'

# %%
# setting the response variable with the website url
# checking the response status

response = requests.get(url)
response.status_code

# status is 200, which means I got something back
# Out:
# 200

# %%
# looking at the response

response.content
# Out:
# b'<!doctype html>\r\n<html prefix="og: http://ogp.me/ns#" class="no-js" xmlns="http://www.w3.org/1999/xhtml" xml:lang="de-de"\r\n      lang="de-de">\r\n    <meta name="description" content="Hier gibt\xe2\x80\x99s die Offiziellen Deutschen Charts in ihrer ganzen Vielfalt. Denn: Hier z\xc3\xa4hlt die Musik." />\r\n<head>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport"\r\n          content="height=device-height, width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=no, minimal-ui">\r\n    <meta name="apple-mobile-web-app-capable" content="yes">\r\n    <link rel="shortcut icon" href="/templates/gfktemplate/favicon.ico">\r\n    <title>Offizielle Deutsche Charts - Offizielle Deutsche Charts</title>\r\n            <link rel="stylesheet"\r\n              href="/templates/gfktemplate/styles/styles.css?v=106">\r\n        <style>\r\n        #gfk-preload {\r\n            position: fixed;\r\n            top: 0;\r\n            left: 0;\r\n            width: 100%;\r\n            height: 100%;\r\n            background: #fff;\r\n            text-align: center;\r\n            padding: 3rem;\r\n            z-index: 99999;\r\n        }\r\n\r\n        .page {\r\n            transition: opacity 0.4s;\r\n            opacity: 1;\r\n        }\r\n\r\n        .page.preload {\r\n            opacity: 0;\r\n        }\r\n    </style>\r\n    <script type="text/javascript" src="https://script.ioam.de/iam.js"> </script>\r\n\t\r\n\t<!-- AD HEADER -->\r\n\t<script src="//imagesrv.adition.com/js/adition.js"></script>\r\n<script src="//admanager.pushfire.de/admanager.min.js "></script>\r\n\r\n<script>AdManager.setParams({\r\n\t\ttop_1: {\r\n\t\t\twp_id: \'4289738\'\r\n        },\r\n\t\tmobile_understitial: {\r\n\t\t\twp_id: \'4289744\'\r\n        }\r\n});\r\n</script>\r\n\r\n<script>AdManager.setConfigs({\r\n\t\ttop_1: {\r\n\t\t\tyieldlab_id: \'6030049\',\r\n\t\t\tyieldlab_check: \'509981\',\r\n\t\t\trequestType: \'javascript\'\r\n\t\t},\r\n\t\tmobile_understitial: {\r\n\t\t\tyieldlab_id: \'6030090\',\r\n\t\t\tyieldlab_check: \'509981\',\r\n\t\t\trequestType: \'javascript\'\r\n\t\t}\r\n});\r\n</script>\r\n\t\t\r\n<script>AdManager.setConditions({\r\n\t\ttop_1: {\r\n\t\t\t \tviewportWidthGt: 1024,\r\n\t\t\t \tmobile: false,\r\n\t\t\t\tdesktop: true,\r\n\t\t},\r\n\t\tmobile_understitial: {\r\n\t\t\t\tmobile: true,\r\n\t\t\t\tdesktop: false,\r\n\t\t}\r\n});\r\n</script>\r\n\r\n<!-- AD HEADER END -->\r\n\t\r\n</head>\r\n<body>\r\n<div id="fb-root"></div>\r\n<script>(function (d, s, id) {\r\n        var js, fjs = d.getElementsByTagName(s)[0];\r\n        if (d.getElementById(id)) return;\r\n        js = d.createElement(s);\r\n        js.id = id;\r\n        js.src = "//connect.facebook.net/de_DE/sdk.js#xfbml=1&version=v2.3&appId=1588684301370978";\r\n        fjs.parentNode.insertBefore(js, fjs);\r\n    }(document, \'script\', \'facebook-jssdk\'));</script>\r\n<div id="gfk-preload">\r\n    <img width="184" height="61" alt="Offizielle Deutsche Charts Logo"\r\n         src="/templates/gfktemplate/images/charts_logo.svg"/><br/><br/>\r\n\r\n    <div id="wrap">\r\n        <img src="/templates/gfktemplate/images/three-dots.svg" alt="preloader" width="40">\r\n    </div>\r\n</div>\r\n<main class="page preload">\r\n    <div class="header">\r\n        <div class="container">\r\n            <div class="top-search text-right hidden-xs">\r\n                <form id="search-form"\r\n                      action="/suche"\r\n                      method="post" class="form-inline pull-right">\r\n                    <div class="form-group">\r\n                        <label for="top-search" class="sr-only">Suche:</label>\r\n\r\n                        <div class="input-search">\r\n                            <input type="search" class="form-control" id="top-search" name="artist_search"\r\n                                   placeholder="Suchen" autocomplete="off">\r\n                            <input type="hidden" name="do_search"  ...

# %%
# lets make it a bit more readable

soup = BeautifulSoup(response.content, 'html.parser')
soup

# looks better now
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="de-de" prefix="og: http://ogp.me/ns#" xml:lang="de-de" xmlns="http://www.w3.org/1999/xhtml">
# <meta content="Hier gibt’s die Offiziellen Deutschen Charts in ihrer ganzen Vielfalt. Denn: Hier zählt die Musik." name="description"/>
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="height=device-height, width=device-width, initial-scale=1.0, maximum-scale=1, user-scalable=no, minimal-ui" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <link href="/templates/gfktemplate/favicon.ico" rel="shortcut icon"/>
# <title>Offizielle Deutsche Charts - Offizielle Deutsche Charts</title>
# <link href="/templates/gfktemplate/styles/styles.css?v=106" rel="stylesheet"/>
# <style>
#         #gfk-preload {
#             position: fixed;
#             top: 0;
#             left: 0;
#             width: 100%;
#             height: 100%;
#             background: #fff;
#             text-align: center;
#             padding: 3rem;
#             z-index: 99999;
#         }
#
#         .page {
#             transition: opacity 0.4s;
#             opacity: 1;
#         }
#
#         .page.preload {
#             opacity: 0;
#         }
#     </style>
# <script src="https://script.ioam.de/iam.js" type="text/javascript"> </script>
# <!-- AD HEADER -->
# <script src="//imagesrv.adition.com/js/adition.js"></script>
# <script src="//admanager.pushfire.de/admanager.min.js "></script>
# <script>AdManager.setParams({
# 		top_1: {
# 			wp_id: '4289738'
#         },
# 		mobile_understitial: {
# 			wp_id: '4289744'
#         }
# });
# </script>
# <script>AdManager.setConfigs({
# 		top_1: {
# 			yieldlab_id: '6030049',
# 			yieldlab_check: '509981',
# 			requestType: 'javascript'
# 		},
# 		mobile_understitial: {
# 			yieldlab_id: '6030090',
# 			yieldlab_check: '509981',
# 			requestType: 'javascript'
# 		}
# });
# </script>
# <script>AdManager.setConditions({
# 		top_1: {
# 			 	viewportWidthGt: 1024,
# 			 	mobile: false,
# 				desktop: true,
# 		},
# 		mobile_understitial: {
# 				mobile: true,
# 				desktop: false,
# 		}
# });
# </script>
# <!-- AD HEADER END -->
# </head>
# <body>
# <div id="fb-root"></div>
# <script>(function (d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s);
#         js.id = id;
#         js.src = "//connect.facebook.net/de_DE/sdk.js#xfbml=1&version=v2.3&appId=1588684301370978";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));</script>
# <div id="gfk-preload">
# <img alt="Offizielle Deutsche Charts Logo" height="61" src="/templates/gfktemplate/images/charts_logo.svg" width="184"/><br/><br/>
# <div id="wrap">
# <img alt="preloader" src="/templates/gfktemplate/images/three-dots.svg" width="40"/>
# </div>
# </div>
# <main class="page preload">
# <div class="header">
# <div class="container">
# <div class="top-search text-right hidden-xs">
# <form action="/suche" class="form-inline pull-right" id="search-form" method="post">
# <div class="form-group">
# <label class="sr-only" for="top-search">Suche:</label>
# <div class="input-search">
# <input autocomplete="off" class="form-control" id="top-search" name="artist_search" placeholder="Suchen" type="search"/>
# <input name="do_search" type="hidden" value="do"/>
# <div class="search-group-addon"><i class="fa fa-search"></i></div>
# </div>
# </div>
# </form>
# <a class="btn btn-primary btn-login" href="/log-in">
#                         Log-In
#                     </a>
# </div>
# </div>
# <nav class="navbar navbar-default">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle collapsed" data-target="#main-navi-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="/"><img alt="Charts Logo" class="img-responsive" src="/templates/gfktemplate/images/charts_logo.svg"/></a>
# </div>
# <div class="collapse navbar-collapse" id="main-navi-collapse">
# <ul class="menu nav navbar-nav nav navbar-right">
# <li class="item-101"><a href="/">Home</a></li><li class="item-120 current active"><a href="/charts">Charts</a></li><li class="item-137"><a href="/news">News</a></li><li class="item-113 deeper parent"><a href="/info">INFO</a><ul class="nav-child unstyled small"><li class="item-140"><a href="/info/faq">FAQ</a></li><li class="item-141"><a href="/info/anleitung">Anleitung</a></li></ul></li></ul>
# <div class="top-search text-right visible-xs">
# <form action="/suche" class="form-inline" id="search-form-2" method="post">
# <div class="form-group">
# <label class="sr-only" for="top-search-navi">Suche:</label>
# <div class="input-search">
# <input autocomplete="off" class="form-control" id="top-search-navi" name="artist_search" placeholder="Suchen" type="search"/>
# <input name="do_search" type="hidden" value="do"/>
# <div class="search-group-addon"><i class="fa fa-search"></i></div>
# </div>
# </div>
# </form>
# <a class="btn btn-primary btn-login" href="/log-in">
#                                 Log-In
#                             </a>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="custom">
# <div style="text-align:center;">
# <script type="text/javascript">
# 	AdManager.createPosition('top_1');
# </script>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-md-8">
# <div class="row">
# <div class="col-md-12">
# <h1 class="big-head">Offizielle Deutsche Charts
#                 <a class="help-link btn btn-primary btn-sm" href="/info/anleitung">i</a>
# </h1>
# <h2 class="sub-head">Top 100 Single-Charts</h2>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12">
# <div class="control-block red-control">
# <div class="row">
# <div class="col-lg-6 col-md-4">
# <h3>Wähle hier deine Charts aus:</h3>
# </div>
# <div class="col-lg-6 col-md-8">
# <div class="dropdown">
# <a aria-expanded="true" class="btn btn-default btn-charts dropdown-toggle" data-toggle="dropdown" href="#" id="dropdownMenu1">
# <span>Single-Charts</span><i class="fa fa-angle-down"></i>
# </a>
# <ul aria-labelledby="dropdownMenu1" class="dropdown-menu dropdown-charts" role="menu">
# <li role="presentation">
# <a href="/charts/single" role="menuitem" tabindex="-1">
# <span class="name-one">Single</span>
#                                             - <span class="name-two">Charts</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/charts/album" role="menuitem" tabindex="-1">
# <span class="name-one">Album</span>
#                                             - <span class="name-two">Charts</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/charts/compilation" role="menuitem" tabindex="-1">
# <span class="name-one">Compilation</span>
#                                             - <span class="name-two">Charts</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/charts/hiphop" role="menuitem" tabindex="-1">
# <span class="name-one">HipHop</span>
#                                             - <span class="name-two">Charts</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/charts/dance" role="menuitem" tabindex="-1">
# <span class="name-one">Dance</span>
#                                             - <span class="name-two">Charts</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/charts/vinyl" role="menuitem" tabindex="-1">
# <span class="name-one">Vinyl</span>
#                                             - <span class="name-two">Charts</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/charts/single-jahr" role="menuitem" tabindex="-1">
# <span class="name-one">Single</span>
#                                             - <span class="name-two"><b class="accent">Jahres</b>charts</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/charts/album-jahr" role="menuitem" tabindex="-1">
# <span class="name-one">Album</span>
#                                             - <span class="name-two"><b class="accent">Jahres</b>charts</span>
# </a>
# </li>
# <li role="presentation">
# <a href="/charts/compilation-jahr" role="menuitem" tabindex="-1">
# <span class="name-one">Compilation</span>
#                                             - <span class="name-two"><b class="accent">Jahres</b>charts</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12">
# <div class="control-block">
# <div class="row">
# <div class="col-lg-6 col-md-4">
# <h3>Wähle hier dein Datum aus:</h3>
# </div>
# <div class="col-lg-6 col-md-8">
# <div class="form-group date-picker">
# <div class="input-group date" data-preload-select="20210507" data-select-max="2021-4-07" data-select-min="1977-0-03" id="datetimepicker-chart">
# <span class="input-group-addon"><span class="glyphicon glyphicon-calendar"></span></span>
# <input class="form-control" type="text">
# </input></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <span class="ch-header">
#         Zeitraum:
#                     <strong>07.05.2021</strong> -
#             <strong>13.05.2021</strong>
# <span class="period-navi">
# <a class="prev-link btn btn-default btn-sm" href="/charts/single/for-date-1619771950000"><i class="fa fa-chevron-left"></i> ZURÜCK</a>
# </span>
# </span>
# <div class="row">
# <div class="col-md-12">
# <table class="table chart-table">
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2145979"></a>
# <span class="this-week">1</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         2                                    </span>
# <i class="trend-up"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2145979_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Nathan Evans</span>
# <span class="info-title">Wellerman</span>
# <span class="info-label">Polydor</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>15                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>1</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/qP-7GNoDJ5c"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2180614"></a>
# <span class="this-week">2</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-new"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2180614_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Cro feat. Capital Bra</span>
# <span class="info-title">Blessed</span>
# <span class="info-label">Urban</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>1                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>2</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/7bEH2LXoT8Q"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2177961"></a>
# <span class="this-week">3</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         3                                    </span>
# </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2177961_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Jamule</span>
# <span class="info-title">Liege wieder wach</span>
# <span class="info-label">Life Is Pain</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>2                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>3</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/yfG7L2lodUc"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2142878"></a>
# <span class="this-week">4</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         7                                    </span>
# <i class="trend-up"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2142878_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Riton x Nightcrawlers feat. Mufasa &amp; Hypeman</span>
# <span class="info-title">Friday (Dopamine Re-Edit)</span>
# <span class="info-label">Columbia</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>12                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>3</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/U6n2NcJ7rLc"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2167980"></a>
# <span class="this-week">5</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         4                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2167980_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Lil Nas X</span>
# <span class="info-title">Montero (Call Me By Your Name)</span>
# <span class="info-label">Columbia</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>6                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>2</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/6swmTBVI83k"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-1971131"></a>
# <span class="this-week">6</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         5                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/1971131_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">The Weeknd</span>
# <span class="info-title">Save Your Tears</span>
# <span class="info-label">Republic Records</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>16                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>5</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/XXYlFuWEuKI"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2150810"></a>
# <span class="this-week">7</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         8                                    </span>
# <i class="trend-up"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2150810_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">P!nk + Willow Sage Hart</span>
# <span class="info-title">Cover Me In Sunshine</span>
# <span class="info-label">RCA</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>10                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>7</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/vGZhMIXH62M"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2169042"></a>
# <span class="this-week">8</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         6                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2169042_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Miksu / Macloud / Jamule / Nimo</span>
# <span class="info-title">Frag mich nicht</span>
# <span class="info-label">Futura</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>6                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>2</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/QxJztwp8N3I"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2177954"></a>
# <span class="this-week">9</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         9                                    </span>
# </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2177954_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Mario Novembre</span>
# <span class="info-title">Allein sein</span>
# <span class="info-label">Green Elephant Records</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>2                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>9</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/OlbFsgWz2MY"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2166506"></a>
# <span class="this-week">10</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         10                                    </span>
# </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2166506_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Justin Bieber feat. Daniel Caesar &amp; Giveon</span>
# <span class="info-title">Peaches</span>
# <span class="info-label">Def Jam</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>7                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>2</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/tQ0yjYUFKAE"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2141839"></a>
# <span class="this-week">11</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         13                                    </span>
# <i class="trend-up"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2141839_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">atb x Topic x A7S</span>
# <span class="info-title">Your Love (9PM)</span>
# <span class="info-label">Virgin Records</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>16                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>6</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/9hbu9toStfc"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2173988"></a>
# <span class="this-week">12</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         12                                    </span>
# </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2173988_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Santos x Sido x Samra</span>
# <span class="info-title">Leere Hände</span>
# <span class="info-label">Urban</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>4                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>2</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/wF_kYX2c3mw"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2156056"></a>
# <span class="this-week">13</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         11                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2156056_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Bausa feat. Apache 207</span>
# <span class="info-title">Madonna</span>
# <span class="info-label">Warner Music Germany</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>11                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>1</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/dKhBE_no8d8"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2182801"></a>
# <span class="this-week">14</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-new"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2182801_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Ufo361</span>
# <span class="info-title">Pinky Ring</span>
# <span class="info-label">Stay High</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>1                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>14</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/uuFmtCDAhko"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2100377"></a>
# <span class="this-week">15</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         25                                    </span>
# <i class="trend-up"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2100377_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">The Kid Laroi</span>
# <span class="info-title">Without You</span>
# <span class="info-label">Columbia</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>19                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>13</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/SJOKlqJho8U"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2172924"></a>
# <span class="this-week">16</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         15                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2172924_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Mark Forster x Lea</span>
# <span class="info-title">Drei Uhr nachts</span>
# <span class="info-label">Four Music</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>4                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>15</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/fDSOhYhORiw"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2180316"></a>
# <span class="this-week">17</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-new"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2180316_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Billie Eilish</span>
# <span class="info-title">Your Power</span>
# <span class="info-label">Interscope</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>1                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>17</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/fzeWc3zh01g&amp;t=10s"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2139576"></a>
# <span class="this-week">18</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         14                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2139576_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Masked Wolf</span>
# <span class="info-title">Astronaut In The Ocean</span>
# <span class="info-label">Elektra</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>17                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>4</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/gXNdCWXO8AM"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2180204"></a>
# <span class="this-week">19</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-new"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2180204_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">RIN</span>
# <span class="info-title">San Andreas</span>
# <span class="info-label">GOLD LEAGUE</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>1                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>19</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/OsnmBHy277A"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2140050"></a>
# <span class="this-week">20</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         16                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2140050_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Zoe Wees</span>
# <span class="info-title">Girls Like Us</span>
# <span class="info-label">Capitol</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>16                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>9</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/ao4giEvkV0U"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2079777"></a>
# <span class="this-week">21</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         18                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2079777_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Tiësto</span>
# <span class="info-title">The Business</span>
# <span class="info-label">Atlantic</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>27                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>3</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/nCg3ufihKyU"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2142107"></a>
# <span class="this-week">22</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         20                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2142107_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Leony</span>
# <span class="info-title">Faded Love</span>
# <span class="info-label">Kontor Records</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>11                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>17</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/CE7ymQByeH0"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2136728"></a>
# <span class="this-week">23</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         19                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2136728_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Ofenbach feat. Lagique</span>
# <span class="info-title">Wasted Love</span>
# <span class="info-label">Elektra</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>10                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>12</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/XzLGcLw3cHc"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2183256"></a>
# <span class="this-week">24</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-new"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2183256_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Fourty x Bausa</span>
# <span class="info-title">Heimkommen</span>
# <span class="info-label">Life Is Pain</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>1                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>24</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/_89xihFJlro"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2175276"></a>
# <span class="this-week">25</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-new"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2175276_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Kontra K</span>
# <span class="info-title">Asphalt &amp; Tennissocken</span>
# <span class="info-label">BMG</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>1                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>25</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/M9dLmR8kDWo"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-1973313"></a>
# <span class="this-week">26</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         21                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/1973313_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Dua Lipa</span>
# <span class="info-title">Levitating</span>
# <span class="info-label">Urban</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>7                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>21</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/TUVcZfQe-Kw"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2173680"></a>
# <span class="this-week">27</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         17                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2173680_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Luciano [DE]</span>
# <span class="info-title">Kids From The Block</span>
# <span class="info-label">Urban</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>4                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>3</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/H1gPjrvlcD0"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2145022"></a>
# <span class="this-week">28</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         27                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2145022_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Wincent Weiss</span>
# <span class="info-title">Wer wenn nicht wir</span>
# <span class="info-label">Universal Domestic Vertigo</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>15                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>12</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/bM7rnfmxic"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2103627"></a>
# <span class="this-week">29</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         22                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2103627_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Jason Derulo x Nuka</span>
# <span class="info-title">Love Not War (The Tampa Beat)</span>
# <span class="info-label">Columbia</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>24                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>9</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/fZMRc-UyPm0"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2033715"></a>
# <span class="this-week">30</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         24                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2033715_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Joel Corry feat. MNEK</span>
# <span class="info-title">Head &amp; Heart</span>
# <span class="info-label">Atlantic</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>42                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>4</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/CRuOOxF-ENQ"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-1924201"></a>
# <span class="this-week">31</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         28                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/1924201_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">The Weeknd</span>
# <span class="info-title">Blinding Lights</span>
# <span class="info-label">Republic Records</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>75                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>1</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/4NRXx6U8ABQ"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2142556"></a>
# <span class="this-week">32</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         23                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2142556_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Kasimir1441 x Badmómzjay</span>
# <span class="info-title">Ohne Dich</span>
# <span class="info-label">1441</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>16                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>1</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/Dc5KpOqkgTI"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2138244"></a>
# <span class="this-week">33</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         29                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2138244_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Olivia Rodrigo</span>
# <span class="info-title">Drivers License</span>
# <span class="info-label">Olivia Rodrigo</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>17                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>2</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/ZmDBbnmKpqQ"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2179969"></a>
# <span class="this-week">34</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-new"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2179969_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Reezy</span>
# <span class="info-title">Manchester</span>
# <span class="info-label">Four Music / TwoSides</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>1                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>34</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/Cloi91UKPBI"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2174528"></a>
# <span class="this-week">35</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         46                                    </span>
# <i class="trend-up"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2174528_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Nimo</span>
# <span class="info-title">Zart</span>
# <span class="info-label">Moonboys Ent.</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>4                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>18</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/ENsmRY_dGEM"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2158664"></a>
# <span class="this-week">36</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         34                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2158664_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Joel Corry, Raye &amp; David Guetta</span>
# <span class="info-title">Bed</span>
# ...
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-ree"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2146626_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Ufo361</span>
# <span class="info-title">No Hugs</span>
# <span class="info-label">Stay High</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>5                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>4</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/SEh_x3ASEf8"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2181141"></a>
# <span class="this-week">98</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
# </span>
# <i class="trend-new"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2181141_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">BHZ</span>
# <span class="info-title">Overdose</span>
# <span class="info-label">Sony Music / BHZ</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>1                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>98</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/S2yigQl5jKI"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2158368"></a>
# <span class="this-week">99</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         75                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2158368_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">T-Low</span>
# <span class="info-title">Ordentlich</span>
# <span class="info-label">Spinnup</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>11                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>19</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/3l22bA2NVu0"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# <tr class="drill-down-link">
# <td class="ch-pos">
# <a class="drill-down" href="/titel-details-2175891"></a>
# <span class="this-week">100</span>
# </td>
# <td class="ch-trend">
# <span class="last-week">
#                                         33                                    </span>
# <i class="trend-down"></i> </td>
# <td class="ch-cover">
# <span class="cover-img" style="background: url('/templates/gfktemplate/images/cover/2175891_s.jpg') top left no-repeat;"></span>
# </td>
# <td class="ch-info">
# <div class="wrap">
# <span class="info-artist">Capital Bra &amp; NGEE</span>
# <span class="info-title">Unter Verdacht</span>
# <span class="info-label">Urban</span>
# <span class="play-media">
# <span class="plus-data">
#                                                     In Charts: <b>3                                                        W</b>
# </span>
# <span class="plus-data">
#                                                     Peak: <b>8</b>
# </span>
# <!-- -->
# <span class="play-video video-more" data-target="https://www.youtube.com/embed/hWI4AWQLDJ8"><i class="glyphicon glyphicon-film"></i></span> </span>
# </div>
# </td>
# </tr>
# </table>
# <div class="partner-add">
# <h6>Die Top 100 schon jetzt bei unseren Partnern:</h6>
# <a href="http://www.viva.tv/charts" target="_blank"><img alt="MTV" src="/templates/gfktemplate/images/MTV_Logo.gif"/></a>
# <a href="http://www.mediabiz.de/musik/charts" target="_blank"><img alt="Musikwoche" src="/templates/gfktemplate/images/partner_logo_musikwoche.gif"/></a>
# </div>
# </div>
# </div>
# <!--
# <pre>
# </pre>
# -->
# </div>
# <!-- mobile Understitial responsive -->
# <div data-admanager-position="understitial" id="understitial">
# <script>
# 			AdManager.createPosition('mobile_understitial');
# 			</script>
# </div>
# <br/>
# <div class="side-bar col-md-4">
# <section class="countdown">
# <h3>Chart Update in</h3>
# <div class="countdown-wrap" data-terminate-time="16" data-terminate-weekday="5">
# </div>
# </section><div class="facebook-box">
# <h3>Facebook</h3>
# <div class="fb-wrap">
# <div class="fb-page" data-height="480" data-hide-cover="false" data-href="https://www.facebook.com/offizielle.deutsche.charts" data-show-facepile="true" data-show-posts="true" data-width="320">
# <div class="fb-xfbml-parse-ignore">
# <blockquote cite="https://www.facebook.com/offizielle.deutsche.charts"><a href="https://www.facebook.com/offizielle.deutsche.charts">Offizielle Deutsche Charts</a></blockquote>
# </div>
# </div>
# </div>
# </div> <div class="twitter-box">
# <h3>Twitter</h3>
# <div class="tweet-slider">
# <div class="slider-tweet">
# <div class="tweet-txt">Album des Tages: Gestern fanden die BRIT Awards statt - und @dualipa wurde als beste britische Künstlerin sowie für… <a class="tweet-link" href="https://t.co/eX4TyRclks" target="_blank">https://t.co/eX4TyRclks</a></div>
# <div class="tweet-footer">
# <span class="tweet-user">
# <a href="https://twitter.com/chartsoffiziell" target="_blank"><img alt="cover" height="48" src="https://pbs.twimg.com/profile_images/596291617172156416/kTb3Cag1_normal.jpg" width="48"/></a>
# <a class="tweet-link" href="https://twitter.com/chartsoffiziell" target="_blank">
# <span>Offizielle</span>
# <span>Deutsche Charts</span>
# </a>
# </span>
# <span class="tweet-actions">
# <a href="https://twitter.com/intent/tweet?in_reply_to=1392471846264713219" target="_blank"><i class="fa fa-share"></i></a>
# <a href="https://twitter.com/intent/retweet?tweet_id=1392471846264713219" target="_blank"><i class="fa fa-retweet"></i></a>
# <a href="https://twitter.com/intent/favorite?tweet_id=1392471846264713219" target="_blank"><i class="fa fa-star"></i></a>
# </span>
# </div>
# </div>
# <div class="slider-tweet">
# <div class="tweet-txt">Sechs Jahre nach „Lost And Found“ meldet sich Oboist Albrecht Mayer an der Spitze der Klassik-Charts zurück - und z… <a class="tweet-link" href="https://t.co/AhocJ3u8mo" target="_blank">https://t.co/AhocJ3u8mo</a></div>
# <div class="tweet-footer">
# <span class="tweet-user">
# <a href="https://twitter.com/chartsoffiziell" target="_blank"><img alt="cover" height="48" src="https://pbs.twimg.com/profile_images/596291617172156416/kTb3Cag1_normal.jpg" width="48"/></a>
# <a class="tweet-link" href="https://twitter.com/chartsoffiziell" target="_blank">
# <span>Offizielle</span>
# <span>Deutsche Charts</span>
# </a>
# </span>
# <span class="tweet-actions">
# <a href="https://twitter.com/intent/tweet?in_reply_to=1392438615935000582" target="_blank"><i class="fa fa-share"></i></a>
# <a href="https://twitter.com/intent/retweet?tweet_id=1392438615935000582" target="_blank"><i class="fa fa-retweet"></i></a>
# <a href="https://twitter.com/intent/favorite?tweet_id=1392438615935000582" target="_blank"><i class="fa fa-star"></i></a>
# </span>
# </div>
# </div>
# <div class="slider-tweet">
# <div class="tweet-txt">Heute vor 40 Jahren starb #BobMarley. Sein Best Of „Legend“ erschien zwar erst posthum, ist mit 93 Wochen aber das… <a class="tweet-link" href="https://t.co/jCNaH34i9M" target="_blank">https://t.co/jCNaH34i9M</a></div>
# <div class="tweet-footer">
# <span class="tweet-user">
# <a href="https://twitter.com/chartsoffiziell" target="_blank"><img alt="cover" height="48" src="https://pbs.twimg.com/profile_images/596291617172156416/kTb3Cag1_normal.jpg" width="48"/></a>
# <a class="tweet-link" href="https://twitter.com/chartsoffiziell" target="_blank">
# <span>Offizielle</span>
# <span>Deutsche Charts</span>
# </a>
# </span>
# <span class="tweet-actions">
# <a href="https://twitter.com/intent/tweet?in_reply_to=1392129652576112640" target="_blank"><i class="fa fa-share"></i></a>
# <a href="https://twitter.com/intent/retweet?tweet_id=1392129652576112640" target="_blank"><i class="fa fa-retweet"></i></a>
# <a href="https://twitter.com/intent/favorite?tweet_id=1392129652576112640" target="_blank"><i class="fa fa-star"></i></a>
# </span>
# </div>
# </div>
# <div class="slider-tweet">
# <div class="tweet-txt">Premiere auf der ISS, danach auf YouTube und bei „American Idol” zu hören: @coldplay haben für „Higher Power” schon… <a class="tweet-link" href="https://t.co/MtstdDbRTx" target="_blank">https://t.co/MtstdDbRTx</a></div>
# <div class="tweet-footer">
# <span class="tweet-user">
# <a href="https://twitter.com/chartsoffiziell" target="_blank"><img alt="cover" height="48" src="https://pbs.twimg.com/profile_images/596291617172156416/kTb3Cag1_normal.jpg" width="48"/></a>
# <a class="tweet-link" href="https://twitter.com/chartsoffiziell" target="_blank">
# <span>Offizielle</span>
# <span>Deutsche Charts</span>
# </a>
# </span>
# <span class="tweet-actions">
# <a href="https://twitter.com/intent/tweet?in_reply_to=1391762134581776391" target="_blank"><i class="fa fa-share"></i></a>
# <a href="https://twitter.com/intent/retweet?tweet_id=1391762134581776391" target="_blank"><i class="fa fa-retweet"></i></a>
# <a href="https://twitter.com/intent/favorite?tweet_id=1391762134581776391" target="_blank"><i class="fa fa-star"></i></a>
# </span>
# </div>
# </div>
# <div class="slider-tweet">
# <div class="tweet-txt">Schon wieder erobern 9 Neueinsteiger die Offiziellen Deutschen HipHop-Charts. Die erfolgreichsten von ihnen sind Uf… <a class="tweet-link" href="https://t.co/jBwULukz4T" target="_blank">https://t.co/jBwULukz4T</a></div>
# <div class="tweet-footer">
# <span class="tweet-user">
# <a href="https://twitter.com/chartsoffiziell" target="_blank"><img alt="cover" height="48" src="https://pbs.twimg.com/profile_images/596291617172156416/kTb3Cag1_normal.jpg" width="48"/></a>
# <a class="tweet-link" href="https://twitter.com/chartsoffiziell" target="_blank">
# <span>Offizielle</span>
# <span>Deutsche Charts</span>
# </a>
# </span>
# <span class="tweet-actions">
# <a href="https://twitter.com/intent/tweet?in_reply_to=1391742639452655620" target="_blank"><i class="fa fa-share"></i></a>
# <a href="https://twitter.com/intent/retweet?tweet_id=1391742639452655620" target="_blank"><i class="fa fa-retweet"></i></a>
# <a href="https://twitter.com/intent/favorite?tweet_id=1391742639452655620" target="_blank"><i class="fa fa-star"></i></a>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="custom">
# <div class="playlist-box">
# <h3>Spotify</h3>
# <p><iframe allowtransparency="true" height="380" src="https://embed.spotify.com/?uri=spotify:user:1130224284:playlist:0HFjjN19YWx5Snx38K5I2v" style="border: none !important;" width="98%"></iframe></p>
# </div></div>
# </div>
# </div>
# </div>
# <footer>
# <div class="top-footer">
# <div class="container">
# <div class="social">
# <div>
# <div class="custom">
# <p><a href="https://facebook.com/offizielle.deutsche.charts" target="_blank"><em class="fa fa-facebook"></em></a><a href="https://twitter.com/chartsoffiziell" target="_blank"><em class="fa fa-twitter"></em></a><a href="https://instagram.com/offizielledeutschecharts" target="_blank"><em class="fa fa-instagram"></em></a>
# </p></div>
# </div>
# </div>
# <div class="footer-nav">
# <ul class="menulist-unstyled list-inline">
# <li class="item-121"><a href="/agb">AGB</a></li><li class="item-122"><a href="/log-in">Login</a></li><li class="item-123"><a href="/impressum">Impressum</a></li><li class="item-124"><a href="/datenschutz">Datenschutz</a></li></ul>
# </div>
# <div class="partner">
# <ul class="list-unstyled list-inline">
# <li><a href="http://www.musikindustrie.de" target="_blank"><img alt="Verband" src="/images/logos/verband_partner_logo.png"/></a></li>
# <li><a href="http://www.gfk-entertainment.com" target="_blank"><img alt="GfK" src="/images/logos/gfk_partner_logo_txt_h58px.png"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="bottom-footer text-right">
# <div class="container">
#                 © 2021 GfK Entertainment            </div>
# </div>
# </footer>
# </main>
# <script src="/templates/gfktemplate/bower_components/modernizr/modernizr.js"></script>
# <script src="/templates/gfktemplate/bower_components/jquery/dist/jquery.js"></script>
# <script src="/templates/gfktemplate/bower_components/bootstrap-sass-official/assets/javascripts/bootstrap.js"></script>
# <script src="/templates/gfktemplate/bower_components/slick-carousel/slick/slick.min.js"></script>
# <script src="/templates/gfktemplate/bower_components/fastclick/lib/fastclick.js"></script>
# <script src="/templates/gfktemplate/bower_components/jquery.debouncedresize/js/jquery.debouncedresize.js"></script>
# <script src="/templates/gfktemplate/bower_components/jquery.countdown/dist/jquery.countdown.js"></script>
# <script src="/templates/gfktemplate/bower_components/pickadate/lib/picker.js"></script>
# <script src="/templates/gfktemplate/bower_components/pickadate/lib/picker.date.js"></script>
# <script src="/templates/gfktemplate/bower_components/jplayer/dist/jplayer/jquery.jplayer.min.js"></script>
# <script src="/templates/gfktemplate/scripts/extra/theme.plugins.js"></script>
# <script src="/templates/gfktemplate/scripts/0_highcharts.custom.js"></script>
# <script src="/templates/gfktemplate/scripts/appl.js?v=106"></script>
# <!--<script src="/templates/gfktemplate/scripts/custom.js?v=106"></script>-->
# <!-- Piwik -->
# <script type="text/javascript">
#         var _paq = _paq || [];
#         _paq.push(['trackPageView']);
#         _paq.push(['enableLinkTracking']);
#         (function () {
#             var u = "//www.gfk-e.com/stats/";
#             _paq.push(['setTrackerUrl', u + 'piwik.php']);
#             _paq.push(['setSiteId', 14]);
#             var d = document, g = d.createElement('script'), s = d.getElementsByTagName('script')[0];
#             g.type = 'text/javascript';
#             g.async = true;
#             g.defer = true;
#             g.src = u + 'piwik.js';
#             s.parentNode.insertBefore(g, s);
#         })();
#     </script>
# <noscript><p><img alt="" src="//www.gfk-e.com/stats/piwik.php?idsite=14" style="border:0;"/></p></noscript>
# <!-- End Piwik Code -->
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#     var iam_data = {
#         "st":"chartsde", // site/domain
#         "cp":"single", // code
#         "sv":"ke", // Es wird eine Befragungseinladung ausgeliefert
# 		"sc": "yes",
#         "co":"Single-Charts" // comment
#     }
#     iom.c(iam_data);
# </script>
# <!--/SZM -->
# <div id="redim-cookiehint"> <div class="cookiecontent">  Cookies erleichtern die Bereitstellung unserer Dienste. Mit der Nutzung unserer Dienste erklären Sie sich damit einverstanden, dass wir Cookies verwenden. </div> <div class="cookiebuttons"> <a class="btn" href="https://www.offiziellecharts.de/datenschutz" id="cookiehintinfo" rel="nofollow">Weitere Informationen</a> <a class="btn" href="https://www.offiziellecharts.de/charts/single/for-date-1620390068000?rCH=2" id="cookiehintsubmit" rel="nofollow">Ok</a> </div> <div class="clr"></div> </div> <script type="text/javascript"> function cookiehintfadeOut(el){  el.style.opacity = 1;   (function fade() {   if ((el.style.opacity -= .1) < 0) {    el.style.display = "none";   } else {    requestAnimationFrame(fade);   }  })(); }    window.addEventListener('load',  function () {  document.getElementById('cookiehintsubmit').addEventListener('click', function (e) {   e.preventDefault();   document.cookie = 'reDimCookieHint=1; expires=Fri, 13 May 2022 23:59:59 GMT;57; path=/';   cookiehintfadeOut(document.getElementById('redim-cookiehint'));   return false;  },false);   } ); </script>
# </body>
# </html>

# %% [markdown]
# ### Scraping Top100 current week
#
# First I am going to scrape the current weeks top100 tracks. If that is successfull, I will try to build a function or a loop which allows me to scrape several pages, dating back until 2010.
#
# I am also going to first get the info I want for one example track to see what I will need in my loop to get all tracks from the first page.

# %%
# getting the current rank

soup.select('td.ch-pos span')[0].text
# Out:
# '1'

# %%
# getting the last weeks rank

soup.select('span.last-week')[0].text
# Out:
# '\n                                        2                                    '

# %%
# getting the artist

soup.select('span.info-artist')[0].text
# Out:
# 'Nathan Evans'

# %%
# getting the track title

soup.select('span.info-title')[0].text
# Out:
# 'Wellerman'

# %%
# getting the label

soup.select('span.info-label')[0].text
# Out:
# 'Polydor'

# %%
# getting the date

soup.select('body > main > div.container > div > div.col-md-8 > span > strong:nth-child(1)')
# Out:
# [<strong>07.05.2021</strong>]

# %%
# 0 is the start date of the week

soup.select('strong')[0].text
# Out:
# '07.05.2021'

# %%
# 1 is the start date of the week

soup.select('strong')[1].text
# Out:
# '13.05.2021'

# %% [markdown]
# Now that I have the individual infos from the track, I am going to build a loop to get info from al tracks from this page.

# %%
# for loop to get artist, title, label, rank, week for all tracks of the specific week

artist = []
title = []
label = []
rank = []
week_start = []
week_end = []

track_lst = soup.select('span.info-title')
len_tracks = len(track_lst)

for track in range(len_tracks):
    artist.append(soup.select('span.info-artist')[track].text)
    title.append(soup.select('span.info-title')[track].text)
    label.append(soup.select('span.info-label')[track].text)
    rank.append(soup.select('td.ch-pos span')[track].text)
    week_start.append(soup.select('strong')[0].text)
    week_end.append(soup.select('strong')[1].text)

# %%
# creating a data frame for the specific week

tracks_2021_cv19 = pd.DataFrame({'artist' : artist, 
                                'title' : title,
                                'label' : label,
                                'rank' : rank,
                                'week_start' : week_start,
                                'week_end' : week_end })

# %%
# this is the df for the top100 of week 19 from 2021

tracks_2021_cv19
# Out:
#                                           artist  \
# 0                                   Nathan Evans
# 1                          Cro feat. Capital Bra
# 2                                         Jamule
# 3   Riton x Nightcrawlers feat. Mufasa & Hypeman
# 4                                      Lil Nas X
# ..                                           ...
# 95                                  Ilira x Vize
# 96                                        Ufo361
# 97                                           BHZ
# 98                                         T-Low
# 99                            Capital Bra & NGEE
#
#                              title                    label rank  week_start  \
# 0                        Wellerman                  Polydor    1  07.05.2021
# 1                          Blessed                    Urban    2  07.05.2021
# 2                Liege wieder wach             Life Is Pain    3  07.05.2021
# 3        Friday (Dopamine Re-Edit)                 Columbia    4  07.05.2021
# 4   Montero (Call Me By Your Name)                 Columbia    5  07.05.2021
# ..                             ...                      ...  ...         ...
# 95                        Dynamite  Epic / Crash Your Sound   96  07.05.2021
# 96                         No Hugs                Stay High   97  07.05.2021
# 97                        Overdose         Sony Music / BHZ   98  07.05.2021
# 98                      Ordentlich                  Spinnup   99  07.05.2021
# 99                  Unter Verdacht                    Urban  100  07.05.2021
#
#       week_end
# 0   13.05.2021
# 1   13.05.2021
# 2   13.05.2021
# 3   13.05.2021
# 4   13.05.2021
# ..         ...
# 95  13.05.2021
# 96  13.05.2021
# 97  13.05.2021
# 98  13.05.2021
# 99  13.05.2021
#
# [100 rows x 6 columns]

# %%
# saving df to csv

tracks_2021_cv19.to_csv('../data/tracks_2021_cv19_raw.csv')

# %% [markdown]
# ### Scraping Top100 several pages
#
# Now that this worked for the first page, I want to get all the pages for all weeks between 2010 and 2021.
#
# **These are the urls:**<br/>
# url current week - https://www.offiziellecharts.de/charts/single/for-date-1620390068000
# <br/><br/>
# url previous week - https://www.offiziellecharts.de/charts/single/for-date-1619733600000
#
# Only the number in the end changes. Unfortunatly there is no pattern behind the number that I recognise.
# However there is a 'previous' button which I can use.
# I have to check how I can access the 'previous' button on the website to loop through all the desired pages and apply the code from above.
# The previous button contains the part of the url that needs to be changed to get the url of the previous page.

# %%
# importing libraries

import re
import numpy as np
from tqdm import tqdm

import datetime

from time import sleep
from random import randint

# %%
# checking how to access the previous button

soup.select('body > main > div.container > div > div.col-md-8 > span > span > a.prev-link.btn.btn-default.btn-sm')
# Out:
# [<a class="prev-link btn btn-default btn-sm" href="/charts/single/for-date-1619771950000"><i class="fa fa-chevron-left"></i> ZURÜCK</a>]

# %%
# checking how to extract the url part and putting it together to form the new url

url = "https://www.offiziellecharts.de" + str([a['href'] for a in soup.select('body > main > div.container > div > div.col-md-8 > span > span > a.prev-link.btn.btn-default.btn-sm')][0]) + "/"
url

# %%
# code inspiration from: https://github.com/jast92/corona-impact-on-DE-music/blob/main/top100/jupyter/01_charts-scrape-multiple.ipynb

url = 'https://www.offiziellecharts.de/charts/single/for-date-1620390068000'

artist = []
title = []
label = []
rank = []
week_start = []
week_end = []
page = 0


while True:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    #finding out the start and end date of the top 100 songs list
    periodhelp = soup.select('strong')
    
    weekdates = []
    for dt in periodhelp:
        weekdates.append(dt.text)
    
    if int(datetime.datetime.strptime(weekdates[0], "%d.%m.%Y").year) == 2009:
        break

    track_lst = soup.select('span.info-title')
    len_tracks = len(track_lst)

    for track in range(len_tracks):
        artist.append(soup.select('span.info-artist')[track].text)
        title.append(soup.select('span.info-title')[track].text)
        label.append(soup.select('span.info-label')[track].text)
        rank.append(soup.select('td.ch-pos span')[track].text)
        week_start.append(soup.select('strong')[0].text)
        week_end.append(soup.select('strong')[1].text)
    page += 1
    print('page', page, 'done' )

    if len(soup.select('body > main > div.container > div > div.col-md-8 > span > span > a.prev-link.btn.btn-default.btn-sm')) > 0:
        url = "https://www.offiziellecharts.de" + str([a['href'] for a in soup.select('body > main > div.container > div > div.col-md-8 > span > span > a.prev-link.btn.btn-default.btn-sm')][0]) + "/"
        continue
    
    elif len(soup.select('body > main > div.container > div > div.col-md-8 > span > span > a.prev-link.btn.btn-default.btn-sm')) <= 0:
        break
    
    
dict_top100 = {'artist' : artist, 
                 'title' : title,
                 'label' : label,
                 'rank' : rank,
                 'week_start' : week_start,
                 'week_end' : week_end}
    
df = pd.DataFrame(dict_top100)
   
df.to_csv('../data/top100_tracks_raw.csv')
# Out:
# page 1 done
# page 2 done
# page 3 done
# page 4 done
# page 5 done
# page 6 done
# page 7 done
# page 8 done
# page 9 done
# page 10 done
# page 11 done
# page 12 done
# page 13 done
# page 14 done
# page 15 done
# page 16 done
# page 17 done
# page 18 done
# page 19 done
# page 20 done
# page 21 done
# page 22 done
# page 23 done
# page 24 done
# page 25 done
# page 26 done
# page 27 done
# page 28 done
# page 29 done
# page 30 done
# page 31 done
# page 32 done
# page 33 done
# page 34 done
# page 35 done
# page 36 done
# page 37 done
# page 38 done
# page 39 done
# page 40 done
# page 41 done
# page 42 done
# page 43 done
# page 44 done
# page 45 done
# page 46 done
# page 47 done
# page 48 done
# page 49 done
# page 50 done
# page 51 done
# page 52 done
# page 53 done
# page 54 done
# page 55 done
# page 56 done
# page 57 done
# page 58 done
# page 59 done
# page 60 done
# page 61 done
# page 62 done
# page 63 done
# page 64 done
# page 65 done
# page 66 done
# page 67 done
# page 68 done
# page 69 done
# page 70 done
# page 71 done
# page 72 done
# page 73 done
# page 74 done
# page 75 done
# page 76 done
# page 77 done
# page 78 done
# page 79 done
# page 80 done
# page 81 done
# page 82 done
# page 83 done
# page 84 done
# page 85 done
# page 86 done
# page 87 done
# page 88 done
# page 89 done
# page 90 done
# page 91 done
# page 92 done
# page 93 done
# page 94 done
# page 95 done
# page 96 done
# page 97 done
# page 98 done
# page 99 done
# page 100 done
# page 101 done
# page 102 done
# page 103 done
# page 104 done
# page 105 done
# page 106 done
# page 107 done
# page 108 done
# page 109 done
# page 110 done
# page 111 done
# page 112 done
# page 113 done
# page 114 done
# page 115 done
# page 116 done
# page 117 done
# page 118 done
# page 119 done
# page 120 done
# page 121 done
# page 122 done
# page 123 done
# page 124 done
# page 125 done
# page 126 done
# page 127 done
# page 128 done
# page 129 done
# page 130 done
# page 131 done
# page 132 done
# page 133 done
# page 134 done
# page 135 done
# page 136 done
# page 137 done
# page 138 done
# page 139 done
# page 140 done
# page 141 done
# page 142 done
# page 143 done
# page 144 done
# page 145 done
# page 146 done
# page 147 done
# page 148 done
# page 149 done
# page 150 done
# page 151 done
# page 152 done
# page 153 done
# page 154 done
# page 155 done
# page 156 done
# page 157 done
# page 158 done
# page 159 done
# page 160 done
# page 161 done
# page 162 done
# page 163 done
# page 164 done
# page 165 done
# page 166 done
# page 167 done
# page 168 done
# page 169 done
# page 170 done
# page 171 done
# page 172 done
# page 173 done
# page 174 done
# page 175 done
# page 176 done
# page 177 done
# page 178 done
# page 179 done
# page 180 done
# page 181 done
# page 182 done
# page 183 done
# page 184 done
# page 185 done
# page 186 done
# page 187 done
# page 188 done
# page 189 done
# page 190 done
# page 191 done
# page 192 done
# page 193 done
# page 194 done
# page 195 done
# page 196 done
# page 197 done
# page 198 done
# page 199 done
# page 200 done
# page 201 done
# page 202 done
# page 203 done
# page 204 done
# page 205 done
# page 206 done
# page 207 done
# page 208 done
# page 209 done
# page 210 done
# page 211 done
# page 212 done
# page 213 done
# page 214 done
# page 215 done
# page 216 done
# page 217 done
# page 218 done
# page 219 done
# page 220 done
# page 221 done
# page 222 done
# page 223 done
# page 224 done
# page 225 done
# page 226 done
# page 227 done
# page 228 done
# page 229 done
# page 230 done
# page 231 done
# page 232 done
# page 233 done
# page 234 done
# page 235 done
# page 236 done
# page 237 done
# page 238 done
# page 239 done
# page 240 done
# page 241 done
# page 242 done
# page 243 done
# page 244 done
# page 245 done
# page 246 done
# page 247 done
# page 248 done
# page 249 done
# page 250 done
# page 251 done
# page 252 done
# page 253 done
# page 254 done
# page 255 done
# page 256 done
# page 257 done
# page 258 done
# page 259 done
# page 260 done
# page 261 done
# page 262 done
# page 263 done
# page 264 done
# page 265 done
# page 266 done
# page 267 done
# page 268 done
# page 269 done
# page 270 done
# page 271 done
# page 272 done
# page 273 done
# page 274 done
# page 275 done
# page 276 done
# page 277 done
# page 278 done
# page 279 done
# page 280 done
# page 281 done
# page 282 done
# page 283 done
# page 284 done
# page 285 done
# page 286 done
# page 287 done
# page 288 done
# page 289 done
# page 290 done
# page 291 done
# page 292 done
# page 293 done
# page 294 done
# page 295 done
# page 296 done
# page 297 done
# page 298 done
# page 299 done
# page 300 done
# page 301 done
# page 302 done
# page 303 done
# page 304 done
# page 305 done
# page 306 done
# page 307 done
# page 308 done
# page 309 done
# page 310 done
# page 311 done
# page 312 done
# page 313 done
# page 314 done
# page 315 done
# page 316 done
# page 317 done
# page 318 done
# page 319 done
# page 320 done
# page 321 done
# page 322 done
# page 323 done
# page 324 done
# page 325 done
# page 326 done
# page 327 done
# page 328 done
# page 329 done
# page 330 done
# page 331 done
# page 332 done
# page 333 done
# page 334 done
# page 335 done
# page 336 done
# page 337 done
# page 338 done
# page 339 done
# page 340 done
# page 341 done
# page 342 done
# page 343 done
# page 344 done
# page 345 done
# page 346 done
# page 347 done
# page 348 done
# page 349 done
# page 350 done
# page 351 done
# page 352 done
# page 353 done
# page 354 done
# page 355 done
# page 356 done
# page 357 done
# page 358 done
# page 359 done
# page 360 done
# page 361 done
# page 362 done
# page 363 done
# page 364 done
# page 365 done
# page 366 done
# page 367 done
# page 368 done
# page 369 done
# page 370 done
# page 371 done
# page 372 done
# page 373 done
# page 374 done
# page 375 done
# page 376 done
# page 377 done
# page 378 done
# page 379 done
# page 380 done
# page 381 done
# page 382 done
# page 383 done
# page 384 done
# page 385 done
# page 386 done
# page 387 done
# page 388 done
# page 389 done
# page 390 done
# page 391 done
# page 392 done
# page 393 done
# page 394 done
# page 395 done
# page 396 done
# page 397 done
# page 398 done
# page 399 done
# page 400 done
# page 401 done
# page 402 done
# page 403 done
# page 404 done
# page 405 done
# page 406 done
# page 407 done
# page 408 done
# page 409 done
# page 410 done
# page 411 done
# page 412 done
# page 413 done
# page 414 done
# page 415 done
# page 416 done
# page 417 done
# page 418 done
# page 419 done
# page 420 done
# page 421 done
# page 422 done
# page 423 done
# page 424 done
# page 425 done
# page 426 done
# page 427 done
# page 428 done
# page 429 done
# page 430 done
# page 431 done
# page 432 done
# page 433 done
# page 434 done
# page 435 done
# page 436 done
# page 437 done
# page 438 done
# page 439 done
# page 440 done
# page 441 done
# page 442 done
# page 443 done
# page 444 done
# page 445 done
# page 446 done
# page 447 done
# page 448 done
# page 449 done
# page 450 done
# page 451 done
# page 452 done
# page 453 done
# page 454 done
# page 455 done
# page 456 done
# page 457 done
# page 458 done
# page 459 done
# page 460 done
# page 461 done
# page 462 done
# page 463 done
# page 464 done
# page 465 done
# page 466 done
# page 467 done
# page 468 done
# page 469 done
# page 470 done
# page 471 done
# page 472 done
# page 473 done
# page 474 done
# page 475 done
# page 476 done
# page 477 done
# page 478 done
# page 479 done
# page 480 done
# page 481 done
# page 482 done
# page 483 done
# page 484 done
# page 485 done
# page 486 done
# page 487 done
# page 488 done
# page 489 done
# page 490 done
# page 491 done
# page 492 done
# page 493 done
# page 494 done
# page 495 done
# page 496 done
# page 497 done
# page 498 done
# page 499 done
# page 500 done
# page 501 done
# page 502 done
# page 503 done
# page 504 done
# page 505 done
# page 506 done
# page 507 done
# page 508 done
# page 509 done
# page 510 done
# page 511 done
# page 512 done
# page 513 done
# page 514 done
# page 515 done
# page 516 done
# page 517 done
# page 518 done
# page 519 done
# page 520 done
# page 521 done
# page 522 done
# page 523 done
# page 524 done
# page 525 done
# page 526 done
# page 527 done
# page 528 done
# page 529 done
# page 530 done
# page 531 done
# page 532 done
# page 533 done
# page 534 done
# page 535 done
# page 536 done
# page 537 done
# page 538 done
# page 539 done
# page 540 done
# page 541 done
# page 542 done
# page 543 done
# page 544 done
# page 545 done
# page 546 done
# page 547 done
# page 548 done
# page 549 done
# page 550 done
# page 551 done
# page 552 done
# page 553 done
# page 554 done
# page 555 done
# page 556 done
# page 557 done
# page 558 done
# page 559 done
# page 560 done
# page 561 done
# page 562 done
# page 563 done
# page 564 done
# page 565 done
# page 566 done
# page 567 done
# page 568 done
# page 569 done
# page 570 done
# page 571 done
# page 572 done
# page 573 done
# page 574 done
# page 575 done
# page 576 done
# page 577 done
# page 578 done
# page 579 done
# page 580 done
# page 581 done
# page 582 done
# page 583 done
# page 584 done
# page 585 done
# page 586 done
# page 587 done
# page 588 done
# page 589 done
# page 590 done
# page 591 done
# page 592 done
# page 593 done
# page 594 done

# %%
# checking, if it worked & how many rows we got

data = pd.read_csv('../data/top100_tracks_raw.csv')
data.shape
# Out:
# (59400, 7)

# %%
# looking at how the data looks like

data.tail()
# Out:
#        Unnamed: 0    artist                        title       label  rank  \
# 59395       59395      a-ha  Nothing Is Keeping You Here  WE LOVE MU    96
# 59396       59396  Coldplay                 Viva la vida  PARLOPHONE    97
# 59397       59397      Sido                   Geburtstag  UDD UNIVER    98
# 59398       59398       Pur                     Irgendwo         EMI    99
# 59399       59399      Inna                          Hot  KONTOR REC   100
#
#        week_start    week_end
# 59395  01.01.2010  07.01.2010
# 59396  01.01.2010  07.01.2010
# 59397  01.01.2010  07.01.2010
# 59398  01.01.2010  07.01.2010
# 59399  01.01.2010  07.01.2010

# %% [markdown]
# Next steps with thie df will be:
#
# - clean up the not needed index column
# - extract the year in a separate column
# - check the individual artist and decide on how to deal with features
# - check outliers like all the christmas songs
# - add another feature called genre
#   -  take the artists from the top20 hip hip charts and assign the genre hip hop to them

# %% [markdown]
# ## Scarping German Top20 Hip Hip charts

# %% [markdown]
# I also want to get the most popular DR albums. Therefore I need to scrape another subsite of the German charts:
# The Top 20 Hip Hop Charts. It should worl with the same code from before, just needs the new url.

# %%
url = 'https://www.offiziellecharts.de/charts/hiphop'

artist = []
title = []
label = []
rank = []
week_start = []
week_end = []
genre = []
page = 0


while True:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    #finding out the start and end date of the top 100 songs list
    periodhelp = soup.select('strong')
    
    weekdates = []
    for dt in periodhelp:
        weekdates.append(dt.text)
    
    if int(datetime.datetime.strptime(weekdates[0], "%d.%m.%Y").year) == 2009:
        break

    track_lst = soup.select('span.info-title')
    len_tracks = len(track_lst)

    for track in range(len_tracks):
        artist.append(soup.select('span.info-artist')[track].text)
        title.append(soup.select('span.info-title')[track].text)
        label.append(soup.select('span.info-label')[track].text)
        rank.append(soup.select('td.ch-pos span')[track].text)
        week_start.append(soup.select('strong')[0].text)
        week_end.append(soup.select('strong')[1].text)
        genre.append('HipHop')
    page += 1
    print('page', page, 'done' )

    if len(soup.select('body > main > div.container > div > div.col-md-8 > span > span > a.prev-link.btn.btn-default.btn-sm')) > 0:
        url = "https://www.offiziellecharts.de" + str([a['href'] for a in soup.select('body > main > div.container > div > div.col-md-8 > span > span > a.prev-link.btn.btn-default.btn-sm')][0]) + "/"
        continue
    
    elif len(soup.select('body > main > div.container > div > div.col-md-8 > span > span > a.prev-link.btn.btn-default.btn-sm')) <= 0:
        break
    
    
dict_hiphop_top20 = {'artist' : artist, 
                 'title' : title,
                 'label' : label,
                 'rank' : rank,
                 'week_start' : week_start,
                 'week_end' : week_end,
                  'genre' : genre}
    
df = pd.DataFrame(dict_hiphop_top20)
   
df.to_csv('../data/top20_hiphop_tracks_raw.csv')
# Out:
# page 1 done
# page 2 done
# page 3 done
# page 4 done
# page 5 done
# page 6 done
# page 7 done
# page 8 done
# page 9 done
# page 10 done
# page 11 done
# page 12 done
# page 13 done
# page 14 done
# page 15 done
# page 16 done
# page 17 done
# page 18 done
# page 19 done
# page 20 done
# page 21 done
# page 22 done
# page 23 done
# page 24 done
# page 25 done
# page 26 done
# page 27 done
# page 28 done
# page 29 done
# page 30 done
# page 31 done
# page 32 done
# page 33 done
# page 34 done
# page 35 done
# page 36 done
# page 37 done
# page 38 done
# page 39 done
# page 40 done
# page 41 done
# page 42 done
# page 43 done
# page 44 done
# page 45 done
# page 46 done
# page 47 done
# page 48 done
# page 49 done
# page 50 done
# page 51 done
# page 52 done
# page 53 done
# page 54 done
# page 55 done
# page 56 done
# page 57 done
# page 58 done
# page 59 done
# page 60 done
# page 61 done
# page 62 done
# page 63 done
# page 64 done
# page 65 done
# page 66 done
# page 67 done
# page 68 done
# page 69 done
# page 70 done
# page 71 done
# page 72 done
# page 73 done
# page 74 done
# page 75 done
# page 76 done
# page 77 done
# page 78 done
# page 79 done
# page 80 done
# page 81 done
# page 82 done
# page 83 done
# page 84 done
# page 85 done
# page 86 done
# page 87 done
# page 88 done
# page 89 done
# page 90 done
# page 91 done
# page 92 done
# page 93 done
# page 94 done
# page 95 done
# page 96 done
# page 97 done
# page 98 done
# page 99 done
# page 100 done
# page 101 done
# page 102 done
# page 103 done
# page 104 done
# page 105 done
# page 106 done
# page 107 done
# page 108 done
# page 109 done
# page 110 done
# page 111 done
# page 112 done
# page 113 done
# page 114 done
# page 115 done
# page 116 done
# page 117 done
# page 118 done
# page 119 done
# page 120 done
# page 121 done
# page 122 done
# page 123 done
# page 124 done
# page 125 done
# page 126 done
# page 127 done
# page 128 done
# page 129 done
# page 130 done
# page 131 done
# page 132 done
# page 133 done
# page 134 done
# page 135 done
# page 136 done
# page 137 done
# page 138 done
# page 139 done
# page 140 done
# page 141 done
# page 142 done
# page 143 done
# page 144 done
# page 145 done
# page 146 done
# page 147 done
# page 148 done
# page 149 done
# page 150 done
# page 151 done
# page 152 done
# page 153 done
# page 154 done
# page 155 done
# page 156 done
# page 157 done
# page 158 done
# page 159 done
# page 160 done
# page 161 done
# page 162 done
# page 163 done
# page 164 done
# page 165 done
# page 166 done
# page 167 done
# page 168 done
# page 169 done
# page 170 done
# page 171 done
# page 172 done
# page 173 done
# page 174 done
# page 175 done
# page 176 done
# page 177 done
# page 178 done
# page 179 done
# page 180 done
# page 181 done
# page 182 done
# page 183 done
# page 184 done
# page 185 done
# page 186 done
# page 187 done
# page 188 done
# page 189 done
# page 190 done
# page 191 done
# page 192 done
# page 193 done
# page 194 done
# page 195 done
# page 196 done
# page 197 done
# page 198 done
# page 199 done
# page 200 done
# page 201 done
# page 202 done
# page 203 done
# page 204 done
# page 205 done
# page 206 done
# page 207 done
# page 208 done
# page 209 done
# page 210 done
# page 211 done
# page 212 done
# page 213 done
# page 214 done
# page 215 done
# page 216 done
# page 217 done
# page 218 done
# page 219 done
# page 220 done
# page 221 done
# page 222 done
# page 223 done
# page 224 done
# page 225 done
# page 226 done
# page 227 done
# page 228 done
# page 229 done
# page 230 done
# page 231 done
# page 232 done
# page 233 done
# page 234 done
# page 235 done
# page 236 done
# page 237 done
# page 238 done
# page 239 done
# page 240 done
# page 241 done
# page 242 done
# page 243 done
# page 244 done
# page 245 done
# page 246 done
# page 247 done
# page 248 done
# page 249 done
# page 250 done
# page 251 done
# page 252 done
# page 253 done
# page 254 done
# page 255 done
# page 256 done
# page 257 done
# page 258 done
# page 259 done
# page 260 done
# page 261 done
# page 262 done
# page 263 done
# page 264 done
# page 265 done
# page 266 done
# page 267 done
# page 268 done
# page 269 done
# page 270 done
# page 271 done
# page 272 done
# page 273 done
# page 274 done
# page 275 done
# page 276 done
# page 277 done
# page 278 done
# page 279 done
# page 280 done
# page 281 done
# page 282 done
# page 283 done
# page 284 done
# page 285 done
# page 286 done
# page 287 done
# page 288 done
# page 289 done
# page 290 done
# page 291 done
# page 292 done
# page 293 done
# page 294 done
# page 295 done
# page 296 done
# page 297 done
# page 298 done
# page 299 done
# page 300 done
# page 301 done
# page 302 done
# page 303 done
# page 304 done
# page 305 done
# page 306 done
# page 307 done
# page 308 done
# page 309 done
# page 310 done
# page 311 done
# page 312 done
# page 313 done
# page 314 done
# page 315 done
# page 316 done
# page 317 done
# page 318 done
# page 319 done
# page 320 done
# page 321 done

# %%
# checking, if it worked & how many rows we got

data2 = pd.read_csv('../data/top20_hiphop_tracks_raw.csv')
data2.shape
# Out:
# (6420, 8)

# %%
# looking at how the data looks like

data2.tail()
# Out:
#       Unnamed: 0      artist              title                     label  \
# 6415        6415    Kollegah               King          Selfmade Records
# 6416        6416  Alligatoah         Triebwerke    Trailerpark Recordings
# 6417        6417      Casper         Hinterland                Four Music
# 6418        6418  Haftbefehl  Russisch Roulette  Universal Domestic Urban
# 6419        6419      Eminem       Curtain Call                Interscope
#
#       rank  week_start    week_end   genre
# 6415    16  23.03.2015  29.03.2015  HipHop
# 6416    17  23.03.2015  29.03.2015  HipHop
# 6417    18  23.03.2015  29.03.2015  HipHop
# 6418    19  23.03.2015  29.03.2015  HipHop
# 6419    20  23.03.2015  29.03.2015  HipHop

# %% [markdown]
# Realised that the data on the top20 hip hop albums are only available until 2015.
